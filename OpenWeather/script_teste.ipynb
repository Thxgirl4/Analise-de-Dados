# %%
import pandas as pd

pd.read_csv('previsao_tempo.csv', sep=';')
# Out:
#     Vel_Km/h  Direcao  Rajada_Km/h Temp_min Temp_max          Descricao  \
# 0        9.0      118         13.0   -252°C   -251°C   nuvens quebradas
# 1       10.0      129         17.0   -252°C   -252°C   nuvens quebradas
# 2       12.0      131         16.0   -250°C   -250°C        chuva fraca
# 3       13.0      144         12.0   -248°C   -248°C        chuva fraca
# 4       17.0      152         16.0   -249°C   -249°C        chuva fraca
# 5       17.0      143         22.0   -251°C   -251°C            nublado
# 6       17.0      137         26.0   -252°C   -252°C            nublado
# 7       14.0      127         22.0   -253°C   -253°C        chuva fraca
# 8       15.0      128         23.0   -253°C   -253°C            nublado
# 9       13.0      130         21.0   -253°C   -253°C            nublado
# 10      13.0      131         18.0   -252°C   -252°C            nublado
# 11      14.0      129         15.0   -249°C   -249°C        chuva fraca
# ...

# %%
pd.read_csv('previsao_tempoBG.csv', sep=';')
# Out:
#     Vel_Km/h  Direcao  Rajada_Km/h Temp_min Temp_max          Descricao  \
# 0        7.0      114          7.0   -259°C   -258°C          céu limpo
# 1        8.0      123          9.0   -260°C   -259°C          céu limpo
# 2       13.0      152         18.0   -255°C   -254°C          céu limpo
# 3       14.0      154         14.0   -247°C   -247°C          céu limpo
# 4       11.0      161         11.0   -245°C   -245°C          céu limpo
# 5       20.0      121         26.0   -248°C   -248°C          céu limpo
# 6       14.0      100         37.0   -254°C   -254°C          céu limpo
# 7       12.0       74         30.0   -257°C   -257°C          céu limpo
# 8       10.0       81         26.0   -257°C   -257°C          céu limpo
# 9        9.0       85         20.0   -257°C   -257°C          céu limpo
# 10      13.0       78         18.0   -252°C   -252°C          céu limpo
# 11      11.0      101         10.0   -245°C   -245°C  céu pouco nublado
# ...
